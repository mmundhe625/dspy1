# %% [markdown]
# <a href="https://colab.research.google.com/github/mmundhe625/dspy1/blob/main/exp6.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# 1. Describe all three data set in terms of following : how many features, their categories (num,text,categorical, nominal,ordinal etc), number of tuples, missing values.
#
# ANS:-
#
#    1. Iris Dataset
#
#    Iris Dataset
#
#     Details:
#
#   * Number of features: 4 input + 1 target = 5 columns
#
#   * Feature types:
#
#        * Sepal Length → Numerical
#
#        * Sepal Width → Numerical
#
#        * Petal Length → Numerical
#
#        * Petal Width → Numerical
#
#        * Species → Categorical (Nominal)
#
#   * Number of tuples (rows): 150
#
#   * Missing values:  No missing values
#
#   2. Air Quality Dataset
#
#    Air Quality Dataset
#
#    Details:
#
#    * Number of features: ~13-15 columns (depends on version)
#
#    * Feature types:
#
#       * CO, NO₂, O₃, Temperature → Numerical
#
#       * Date, Time → Text / Temporal
#
#       * Sensor readings → Numerical
#
#    * Categories:
#
#       * Mostly Numerical
#
#       * Some Text / Date-Time
#
#    * Number of tuples: ~9358
#
#    * Missing values:  Yes (many missing values, often marked as -200)
#    3. Wine Quality Dataset
#
#      Wine Quality Dataset
#
#       Details:
#
#       * Number of features: 11 input + 1 output = 12 columns
#
#       * Feature types:
#
#            * Fixed acidity, pH, alcohol, etc. → Numerical
#
#            * Quality → Categorical (Ordinal)
#
#       * Categories:
#
#            * Input features → Numerical
#
#            * Output (quality score 0-10) → Ordinal
#
#       * Number of tuples:
#
#            * Red wine → 1599
#
#            * White wine → 4898
#
#       * Missing values:  No missing values

# %% [markdown]
# 2. In IRIS data set which non graphical EDA is performed ?
#
#
# ANS:-
#
# In the Iris Dataset, Non-Graphical Exploratory Data Analysis (EDA) means analyzing the data using numerical summaries instead of plots or charts.
#
# Non-Graphical EDA performed on Iris Dataset
#
# 1) Summary Statistics
#
# * Mean
#
# * Median
#
# * Mode
#
# * Minimum and Maximum
#
# * Standard Deviation
#
# * Variance
#
# 2) Count of Observations
#
# * Total number of samples (150)
#
# * Number of samples in each species:
#
#        * Setosa - 50
#
#        * Versicolor - 50
#
#        * Virginica - 50
#
# 3)Five Number Summary
#
# * Minimum
#
# * First Quartile (Q1)
#
# * Median (Q2)
#
# * Third Quartile (Q3)
#
# * Maximum
#
# 4)Missing Value Analysis
#
# * Check if any values are NULL / NaN in the dataset.
#
# 5)Correlation Matrix
#
# * Measure relationship between variables like:
#
#        * Sepal Length
#
#        * Sepal Width
#
#        * Petal Length
#
#        * Petal Width
#  6)Data Types and Structure
#
#     * Checking column types (float, object, etc.)
#
#     * Number of rows and columns.

# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import warnings
warnings.filterwarnings('ignore')

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-8f1a4dd0-45b4-4865-83a2-d614253ee4f1" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-8f1a4dd0-45b4-4865-83a2-d614253ee4f1">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
df = pd.read_csv('Iris.csv')
df.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %% [markdown]
# 3. In  Air Quality data set which graph is used to perform multivariate analysis?
#
# ANS:-
#
# In the Air Quality dataset, the most commonly used graph for multivariate analysis is:
#
# Pair Plot (Scatter Plot Matrix)

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-9a76b57c-ab20-4b0b-a560-bf488fcd1085" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-9a76b57c-ab20-4b0b-a560-bf488fcd1085">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import seaborn as sns
import pandas as pd

df = pd.read_csv("AQI.csv")

sns.pairplot(df)

# %% [markdown]
# 4. In Wine quality data set can you do non graphical EDA ? Explain your answer.
#
# ANS:-
#
# Non-Graphical EDA on Wine Quality Dataset
# 1. Dataset Structure
#
#  * Check number of rows and columns
#
#  * Identify feature names (e.g., acidity, alcohol, pH, quality)

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-d991ff2e-c83b-4060-af9f-8d1c21f772de" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-d991ff2e-c83b-4060-af9f-8d1c21f772de">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
df.shape
df.columns
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16695 entries, 0 to 16694
# Data columns (total 14 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Country             16393 non-null  object
#  1   City                16695 non-null  object
#  2   AQI Value           16695 non-null  int64
#  3   AQI Category        16695 non-null  object
#  4   CO AQI Value        16695 non-null  int64
#  5   CO AQI Category     16695 non-null  object
#  6   Ozone AQI Value     16695 non-null  int64
#  7   Ozone AQI Category  16695 non-null  object
#  8   NO2 AQI Value       16695 non-null  int64
#  9   NO2 AQI Category    16695 non-null  object
#  10  PM2.5 AQI Value     16695 non-null  int64
#  11  PM2.5 AQI Category  16695 non-null  object
#  12  lat                 16695 non-null  float64
#  13  lng                 16695 non-null  float64
# dtypes: float64(2), int64(5), object(7)
# memory usage: 1.8+ MB

# %% [markdown]
# 2. Summary Statistics
#
#    * Mean, Median
#
#    * Minimum & Maximum
#
#    * Standard Deviation

# %%
df.describe()
# Out:
#           AQI Value  CO AQI Value  Ozone AQI Value  NO2 AQI Value  \
# count  16695.000000  16695.000000     16695.000000   16695.000000
# mean      62.998682      1.342138        31.767355       3.819647
# std       43.091971      2.371379        22.839343       5.880677
# min        7.000000      0.000000         0.000000       0.000000
# 25%       38.500000      1.000000        20.000000       0.000000
# 50%       52.000000      1.000000        29.000000       2.000000
# 75%       69.000000      1.000000        38.000000       5.000000
# max      500.000000    133.000000       222.000000      91.000000
#
#        PM2.5 AQI Value           lat           lng
# count     16695.000000  16695.000000  16695.000000
# mean         59.821324     30.267148     -3.944485
# std          43.208298     22.947398     73.037148
# min           0.000000    -54.801900   -171.750000
# 25%          34.000000     16.515450    -75.180000
# 50%          52.000000     38.815800      5.643100
# ...

# %% [markdown]
# Helps understand distribution of features like:
#
#  * Alcohol
#
#  * pH
#
#  * Residual sugar

# %% [markdown]
# 3. Missing Value Analysis
#
#    Check for null values:

# %%
df.isnull().sum()
# Out:
# Country               302
# City                    0
# AQI Value               0
# AQI Category            0
# CO AQI Value            0
# CO AQI Category         0
# Ozone AQI Value         0
# Ozone AQI Category      0
# NO2 AQI Value           0
# NO2 AQI Category        0
# PM2.5 AQI Value         0
# PM2.5 AQI Category      0
# lat                     0
# lng                     0
# dtype: int64

# %% [markdown]
# 4. Quality Distribution
#
#   Check how many samples belong to each quality score:

# %%
import pandas as pd

df = pd.read_csv('winequality-white.csv', sep=';')
df['quality'].value_counts()
# Out:
# quality
# 6    2198
# 5    1457
# 7     880
# 8     175
# 4     163
# 3      20
# 9       5
# Name: count, dtype: int64

# %% [markdown]
# 5. Correlation Analysis
#
#    Find relationships between variables:

# %%
df.corr()
# Out:
#                       fixed acidity  volatile acidity  citric acid  \
# fixed acidity              1.000000         -0.022697     0.289181
# volatile acidity          -0.022697          1.000000    -0.149472
# citric acid                0.289181         -0.149472     1.000000
# residual sugar             0.089021          0.064286     0.094212
# chlorides                  0.023086          0.070512     0.114364
# free sulfur dioxide       -0.049396         -0.097012     0.094077
# total sulfur dioxide       0.091070          0.089261     0.121131
# density                    0.265331          0.027114     0.149503
# pH                        -0.425858         -0.031915    -0.163748
# sulphates                 -0.017143         -0.035728     0.062331
# alcohol                   -0.120881          0.067718    -0.075729
# quality                   -0.113663         -0.194723    -0.009209
#
#                       residual sugar  chlorides  free sulfur dioxide  \
# ...

# %% [markdown]
# Important observation:
#
#   * Alcohol often has positive correlation with quality
#
#   * Volatile acidity often has negative correlation

# %% [markdown]
# 6. Five Number Summary
#
#    Min, Q1, Median, Q3, Max

# %%
df.describe()
# Out:
#        fixed acidity  volatile acidity  citric acid  residual sugar  \
# count    4898.000000       4898.000000  4898.000000     4898.000000
# mean        6.854788          0.278241     0.334192        6.391415
# std         0.843868          0.100795     0.121020        5.072058
# min         3.800000          0.080000     0.000000        0.600000
# 25%         6.300000          0.210000     0.270000        1.700000
# 50%         6.800000          0.260000     0.320000        5.200000
# 75%         7.300000          0.320000     0.390000        9.900000
# max        14.200000          1.100000     1.660000       65.800000
#
#          chlorides  free sulfur dioxide  total sulfur dioxide      density  \
# count  4898.000000          4898.000000           4898.000000  4898.000000
# mean      0.045772            35.308085            138.360657     0.994027
# std       0.021848            17.007137             42.498065     0.002991
# ...

# %% [markdown]
# 7. Data Types

# %%
df.dtypes
# Out:
# fixed acidity           float64
# volatile acidity        float64
# citric acid             float64
# residual sugar          float64
# chlorides               float64
# free sulfur dioxide     float64
# total sulfur dioxide    float64
# density                 float64
# pH                      float64
# sulphates               float64
# alcohol                 float64
# quality                   int64
# dtype: object
