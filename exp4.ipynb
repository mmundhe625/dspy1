# %% [markdown]
# <a href="https://colab.research.google.com/github/mmundhe625/dspy1/blob/main/exp4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Aim :**
#
# Learn use of maplotlib library as visualisation tool in data science pipeline to create contour plots, histograms and box plots.
#
# **Performance :**
#
# [Students need to execute each and every cell in this section and note the output of the same. Once done they have to answer Questions mentioned in review section]
#
# **Density and Contour plots**
#
# Sometimes it is useful to display three-dimensional data in two dimensions using contours or color-coded regions.
#
# There are three Matplotlib functions that can be helpful for this task: plt.contour for contour plots, plt.contourf for filled contour plots, and plt.imshow for showing images.
#
# We will see examples of this type of plot in section below

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
plt.style.use('seaborn-v0_8-white')
import numpy as np

# %%
def f(x, y):
    return np.sin(x) ** 10 + np.cos(10 + y * x) * np.cos(x)

# %% [markdown]
# A contour plot can be created with the plt.contour function. It takes three arguments: a grid of x values, a grid of y values, and a grid of z values.
#
# The x and y values represent positions on the plot, and the z values will be represented by the contour levels.
#
# Perhaps the most straightforward way to prepare such data is to use the np.meshgrid function, which builds two-dimensional grids from one-dimensional arrays:

# %%
x = np.linspace(0, 5, 50)
y = np.linspace(0, 5, 40)

X, Y = np.meshgrid(x, y)
Z = f(X, Y)

# %%
plt.contour(X, Y, Z, colors='black');

# %%
plt.contour(X, Y, Z, cmap='RdGy');

# %%
plt.contour(X, Y, Z, 20, cmap='RdGy');
plt.colorbar();

# %% [markdown]
# 1. Explain what are the changes you observe in contour plots above 3 code cells ?
#
# ANS:-
#
#
# Cell ircclm4uG6Cc:
#
# plt.contour(X, Y, Z, colors='black');
# Observation: This cell creates a basic contour plot. The contour lines are all rendered in black, and the number of contour levels is determined by Matplotlib's default settings (usually around 8-10 levels).
# Cell 7MdEJjsKG-0u:
#
# plt.contour(X, Y, Z, cmap='RdGy');
# Observation: The primary change here is the introduction of a colormap (cmap='RdGy'). Instead of black lines, the contour lines are now colored according to the RdGy colormap, where different colors represent different Z values. The number of contour levels remains at the default.
# Cell r7jIqsx7HE_n:
#
# plt.contour(X, Y, Z, 20, cmap='RdGy');
# plt.colorbar();
# Observation: This cell introduces two significant changes:
# The third argument, 20, explicitly sets the number of contour levels to 20. This results in a more detailed plot with more contour lines, providing a finer resolution of the underlying function f(X,Y).
# plt.colorbar() is added. This displays a color bar next to the plot, which serves as a legend for the RdGy colormap, showing the mapping between the colors of the contour lines and the actual Z values they represent.
#
#
# 2.  What is size of X, Y and Z respectively ?
#
# ANS:-
# The size of X is (40, 50).
#
# The size of Y is (40, 50).
#
# The size of Z is also (40, 50).
#
#
# 3. How does colorbar() method help in contour plot.
#
# ANS:-
#
#  Interpretation of Z-values:
#   It allows you to quickly understand the magnitude of the underlying data (Z) at different points on the 2D plot. For instance, in your example with cmap='RdGy', the colorbar shows you which shades of red correspond to higher Z values and which shades of gray (or other colors in the colormap) correspond to lower Z values.
#
# Quantitative Analysis:
#  It makes the plot quantitative. You can look at a specific contour line, find its color on the colorbar, and immediately know the approximate value of Z along that contour.
#
# Clarity and Completeness:
# It makes the plot self-explanatory and complete, removing ambiguity about what the different colors signify.

# %% [markdown]
# **Creating Smoother Contour Plots**
#
# One potential issue with this plot is that it is a bit "splotchy." That is, the color steps are discrete rather than continuous, which is not always what is desired.
#
# This could be remedied by setting the number of contours to a very high number, but this results in a rather inefficient plot: Matplotlib must render a new polygon for each step in the level. A better way to handle this is to use the plt.imshow() function, which interprets a two-dimensional grid of data as an image.
#
# The following code shows how to perform this:

# %%
plt.imshow(Z, extent=[0, 5, 0, 5], origin='lower',
           cmap='RdGy')
plt.colorbar()
plt.axis('image');
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-274/3042752529.py in <cell line: 0>()
#       2            cmap='RdGy')
#       3 plt.colorbar()
# ----> 4 plt.axis(aspect='image');
#
# /usr/local/lib/python3.12/dist-packages/matplotlib/pyplot.py in axis(arg, emit, **kwargs)
#    2938     **kwargs,
#    2939 ) -> tuple[float, float, float, float]:
# -> 2940     return gca().axis(arg, emit=emit, **kwargs)
#    2941
#    2942
#
# /usr/local/lib/python3.12/dist-packages/matplotlib/axes/_base.py in axis(self, arg, emit, **kwargs)
#    2193                 set_ax_lim(ax_min, ax_max, emit=emit, auto=ax_auto)
#    2194         if kwargs:
# -> 2195             raise _api.kwarg_error("axis", kwargs)
#    2196         lims = ()
#    2197         for name in self._axis_names:
#
# TypeError: axis() got an unexpected keyword argument 'aspect'

# %%
from google.colab import drive
drive.mount('/content/drive')

# %% [markdown]
# Things to remember while using imshow():
#
#
# * plt.imshow() doesn't accept an x and y grid, so you must manually specify the extent [xmin, xmax, ymin, ymax] of the image on the plot.
# *  plt.imshow() by default follows the standard image array definition where the origin is in the upper left, not in the lower left as in most contour plots. This must be changed when showing gridded data.
#
#
# * plt.imshow() will automatically adjust the axis aspect ratio to match the input data; this can be changed by setting, for example, plt.axis(aspect='image') to make x and y units match.

# %%
contours = plt.contour(X, Y, Z, 5, colors='black')
plt.clabel(contours, inline=True, fontsize=8)

plt.imshow(Z, extent=[0, 5, 0, 5], origin='lower',
           cmap='RdGy', alpha=0.5)
plt.colorbar();

# %% [markdown]
# Histogram, Binning Plots
# A histogram is a graphical representation of a grouped frequency distribution with continuous classes. It is an area diagram and can be defined as a set of rectangles with bases along with the intervals between class boundaries and with areas proportional to frequencies in the corresponding classes. In such representations, all the rectangles are adjacent since the base covers the intervals between class boundaries. The heights of rectangles are proportional to corresponding frequencies of similar classes and for different classes, the heights will be proportional to corresponding frequency densities.
#
# In other words, a histogram is a diagram involving rectangles whose area is proportional to the frequency of a variable and width is equal to the class interval.
#
# The histogram graph is used under certain conditions. They are:
#
#
#
# * The data should be numerical.
#
# *   A histogram is used to check the shape of the data distribution.
# *   Used to check whether the process changes from one period to another.
#
#
# *   Used to determine whether the output is different when it involves two or more processes.
#
# * Used to analyse whether the given process meets the customer requirements.

# %%
data = np.random.randn(1000)
plt.hist(data);

# %%
plt.hist(data, bins=30, alpha=0.5, histtype='stepfilled', color='steelblue', edgecolor='none');

# %%
x1 = np.random.normal(0, 0.8, 1000)
x2 = np.random.normal(-2, 1, 1000)
x3 = np.random.normal(3, 2, 1000)

kwargs = dict(histtype='stepfilled', alpha=0.3, bins=40)

plt.hist(x1, **kwargs)
plt.hist(x2, **kwargs)
plt.hist(x3, **kwargs);

# %%
counts, bin_edges = np.histogram(data, bins=5)
print(counts,bin_edges)
# Out:
# [ 19 184 435 316  46] [-3.26076298 -2.03981641 -0.81886984  0.40207673  1.62302331  2.84396988]

# %% [markdown]
# **plt.hist2d: Two-dimensional histogram**
#
# One straightforward way to plot a two-dimensional histogram is to use Matplotlib's plt.hist2d function:

# %%
mean = [0, 0]
cov = [[1, 1], [1, 2]]
x, y = np.random.multivariate_normal(mean, cov, 10000).T

# %%
plt.hist2d(x, y, bins=30, cmap='Blues')
cb = plt.colorbar()
cb.set_label('counts in bin')

# %%
counts, xedges, yedges = np.histogram2d(x, y, bins=30)

# %% [markdown]
# **plt.hexbin: Hexagonal binnings**
#
# The two-dimensional histogram creates a tesselation of squares across the axes. Another natural shape for such a tesselation is the regular hexagon. For this purpose, Matplotlib provides the plt.hexbin routine, which will represents a two-dimensional dataset binned within a grid of hexagons:

# %%
plt.hexbin(x, y, gridsize=30, cmap='Blues')
cb = plt.colorbar(label='count in bin')

# %% [markdown]
# 1. What is role of bins parameter in histogram plot?
#
# ANS:-
#
# The bins parameter in a histogram plot defines the number of intervals or ranges into which the data is divided. Each bin collects data points that fall within its specified range, and the height of the bar for that bin represents the frequency or count of data points in that particular interval.
#
#
# 2. Create a set of 10000 uniform random samples and store it in variable named norm_data. Draw histograms of norm_data with following bin counts 5, 50, 500, 5000.
#
# ANS:-
# Generate Uniform Random Samples:
#  Create a NumPy array named norm_data containing 10,000 uniform random samples using np.random.rand().
# Plot Histograms with Different Bin Counts:
#  Generate four separate histogram plots of norm_data using plt.hist(). Each plot will use a different bins parameter value: 5, 50, 500, and 5000. Ensure appropriate titles and labels for each plot for clarity. The plots should demonstrate the visual effect of varying bin counts on the representation of the data's distribution.
# Explain Observations on Bin Counts:
# Add a text cell explaining the observations from the generated histograms. Describe how changing the bins parameter affects the visualization of the data distribution, specifically noting the impact of too few bins (oversimplification) and too many bins (noise/over-detail), and what a 'good' number of bins reveals about the underlying distribution.
# 3. Explain your observations in text box of above step.
#
# ANS:-
#
# Explain Observations on Bin Counts:
#  Provide a detailed explanation of the observations made from hypothetical histograms generated with 5, 50, 500, and 5000 bins for 10,000 uniform random samples. This explanation should highlight how too few bins oversimplify, too many bins introduce noise, and an optimal number reveals the true distribution. This will be presented as if it were to be put into a text cell in the notebook.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import pandas as pd
cities = pd.read_csv('/content/drive/MyDrive/Colab/california_cities.csv')

# Extract the data we're interested in
lat, lon = cities['latd'], cities['longd']
population, area = cities['population_total'], cities['area_total_km2']

# Scatter the points, using size and color but no label
plt.scatter(lon, lat, label=None,
            c=np.log10(population), cmap='viridis',
            s=area, linewidth=0, alpha=0.5)
plt.axis(aspect='equal')
plt.xlabel('longitude')
plt.ylabel('latitude')
plt.colorbar(label='log(population)')
plt.clim(3, 7)

# Here we create a legend:
# we'll plot empty lists with the desired size and label
for area in [100, 300, 500]:
    plt.scatter([], [], c='k', alpha=0.3, s=area,
                label=str(area) + ' km')
plt.legend(scatterpoints=1, frameon=False, labelspacing=1, title='City Area')

plt.title('California Cities: Area and Population');
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-274/1665559489.py in <cell line: 0>()
#      10             c=np.log10(population), cmap='viridis',
#      11             s=area, linewidth=0, alpha=0.5)
# ---> 12 plt.axis(aspect='equal')
#      13 plt.xlabel('longitude')
#      14 plt.ylabel('latitude')
#
# /usr/local/lib/python3.12/dist-packages/matplotlib/pyplot.py in axis(arg, emit, **kwargs)
#    2938     **kwargs,
#    2939 ) -> tuple[float, float, float, float]:
# -> 2940     return gca().axis(arg, emit=emit, **kwargs)
#    2941
#    2942
#
# /usr/local/lib/python3.12/dist-packages/matplotlib/axes/_base.py in axis(self, arg, emit, **kwargs)
#    2193                 set_ax_lim(ax_min, ax_max, emit=emit, auto=ax_auto)
#    2194         if kwargs:
# -> 2195             raise _api.kwarg_error("axis", kwargs)
#    2196         lims = ()
#    2197         for name in self._axis_names:
#
# TypeError: axis() got an unexpected keyword argument 'aspect'

# %% [markdown]
# **Multiple Subplots**
#
# Sometimes it is helpful to compare different views of data side by side. Matplotlib has the concept of subplots : groups of smaller axes that can exist together within a single figure.
#
# These subplots might be insets, grids of plots, or other more complicated layouts.

# %%
plt.style.use('seaborn-v0_8-white')
import numpy as np

# %% [markdown]
# **plt.axes: Subplots by Hand (Coding)**
#
# The most basic method of creating an axes is to use the plt.axes function. By default this creates a standard axes object that fills the entire figure.
#
# plt.axes also takes an optional argument that is a list of four numbers in the figure coordinate system. These numbers represent [left, bottom, width, height] in the figure coordinate system, which ranges from 0 at the bottom left of the figure to 1 at the top right of the figure.
#
# For example, we might create an inset axes at the top-right corner of another axes by setting the x and y position to 0.65 (that is, starting at 65% of the width and 65% of the height of the figure) and the x and y extents to 0.2 (that is, the size of the axes is 20% of the width and 20% of the height of the figure):

# %%
ax1 = plt.axes()  # standard axes
ax2 = plt.axes([0.650, 0.650, 0.2, 0.2]) #inset axes

# %%
fig = plt.figure()
ax1 = fig.add_axes([0.1, 0.5, 0.8, 0.4],
                   xticklabels=[], ylim=(-1.2, 1.2))
ax2 = fig.add_axes([0.1, 0.1, 0.8, 0.4],
                   ylim=(-1.2, 1.2))

x = np.linspace(0, 10)
ax1.plot(np.sin(x))
ax2.plot(np.cos(x));

# %% [markdown]
# **plt.subplot: Simple Grids of Subplots**
#
# Aligned columns or rows of subplots are a common-enough need that Matplotlib has several convenience routines that make them easy to create.
#
# The lowest level of these is plt.subplot(), which creates a single subplot within a grid.
#
# As you can see, this command takes three integer arguments—the number of rows, the number of columns, and the index of the plot to be created in this scheme, which runs from the upper left to the bottom right:

# %%
for i in range(1, 9):
    plt.subplot(2, 4, i)
    plt.text(0.5, 0.5, str((2, 3, i)), fontsize=18, ha='center')

# %%
fig = plt.figure()
fig.subplots_adjust(hspace=0.4, wspace=0.4)
for i in range(1, 7):
    ax = fig.add_subplot(2, 3, i)
    ax.text(0.5, 0.5, str((2, 3, i)),
           fontsize=18, ha='center')

# %% [markdown]
# **plt.subplots: The Whole Grid in One Go**
#
# The approach just described can become quite tedious when creating a large grid of subplots, especially if you'd like to hide the x- and y-axis labels on the inner plots. For this purpose, plt.subplots() is the easier tool to use (note the s at the end of subplots). Rather than creating a single subplot, this function creates a full grid of subplots in a single line, returning them in a NumPy array. The arguments are the number of rows and number of columns, along with optional keywords sharex and sharey, which allow you to specify the relationships between different axes.
#
# Here we'll create a
#  grid of subplots, where all axes in the same row share their y-axis scale, and all axes in the same column share their x-axis scale:

# %%
fig, ax = plt.subplots(2, 3, sharex='col', sharey='row')

# %%
for i in range(2):
    for j in range(3):
        ax[i, j].text(0.5, 0.5, str((i, j)),
                      fontsize=18, ha='center')
fig

# %%
mean = [0, 0]
cov = [[1, 1], [1, 2]]
x, y = np.random.multivariate_normal(mean, cov, 3000).T

# Set up the axes with gridspec
fig = plt.figure(figsize=(6, 6))
grid = plt.GridSpec(4, 4, hspace=0.2, wspace=0.2)
main_ax = fig.add_subplot(grid[:-1, 1:])
y_hist = fig.add_subplot(grid[:-1, 0], xticklabels=[], sharey=main_ax)
x_hist = fig.add_subplot(grid[-1, 1:], yticklabels=[], sharex=main_ax)

# scatter points on the main axes
main_ax.plot(x, y, 'ok', markersize=3, alpha=0.2)

# histogram on the attached axes
x_hist.hist(x, 40, histtype='stepfilled',
            orientation='vertical', color='gray')
x_hist.invert_yaxis()

y_hist.hist(y, 40, histtype='stepfilled',
            orientation='horizontal', color='gray')
y_hist.invert_xaxis()

# %%
import matplotlib as mpl
# An example of Complex Plotting
births = pd.read_csv('/content/drive/MyDrive/Colab/births.csv')

quartiles = np.percentile(births['births'], [25, 50, 75])
mu, sig = quartiles[1], 0.74 * (quartiles[2] - quartiles[0])
births = births.query('(births > @mu - 5 * @sig) & (births < @mu + 5 * @sig)')

births['day'] = births['day'].astype(int)

births.index = pd.to_datetime(10000 * births.year +
                              100 * births.month +
                              births.day, format='%Y%m%d')
births_by_date = births.pivot_table('births',[births.index.month, births.index.day])
births_by_date.index = [pd.Timestamp(2012, month, day)
 for (month, day) in births_by_date.index]

# %%
fig, ax = plt.subplots(figsize=(12, 4))
births_by_date.plot(ax=ax);

# %% [markdown]
# **Boxplot**
#
# A Box Plot is also known as Whisker plot is created to display the summary of the set of data values having properties like minimum, first quartile, median, third quartile and maximum.
#
# In the box plot, a box is created from the first quartile to the third quartile, a vertical line is also there which goes through the box at the median. Here x-axis denotes the data to be plotted while the y-axis shows the frequency distribution.

# %%
import matplotlib.pyplot as plt
import numpy as np


# Creating dataset
np.random.seed(10)

data_1 = np.random.normal(100, 10, 200)
data_2 = np.random.normal(90, 20, 200)
data_3 = np.random.normal(80, 30, 200)
data_4 = np.random.normal(70, 40, 200)
data = [data_1, data_2, data_3, data_4]

fig = plt.figure(figsize =(10, 7))

# Creating axes instance
ax = fig.add_axes([0, 0, 1, 1])

# Creating plot
bp = ax.boxplot(data)

# show plot
plt.show()

# %% [markdown]
# **Questions:**
#
# 1. What is boxplot ?
#
# ANS:-
# A Box Plot, also known as a Whisker Plot, is a graphical representation designed to summarize the distribution of a dataset.
#
# 2. What information do we get from a box plot?
#
# ANS:-
#
# A box plot provides a wealth of information about the distribution of a dataset at a glance.
#
# 3. How is minimum and maximum whisker's marked in a box plot ?
#
# ANS:-
#
# In a box plot, the minimum and maximum whiskers are typically marked based on the Interquartile Range (IQR) and are designed to show the spread of the data while identifying potential outliers.
#
# 4. How to we identify that some points in data are outliers by viewing the box plot?
#
# ANS:-
#
# In a box plot, the whiskers extend from the box to the lowest and highest data points that are not considered outliers. These whiskers typically cover data points within 1.5 times the Interquartile Range (IQR) from the first (Q1) and third (Q3) quartiles.
# Any individual data points plotted as dots, circles, asterisks, or other distinct markers that fall outside or beyond these whiskers are considered outliers.
# Understand the Whisker Boundaries:
#
# The upper whisker ends at the largest data value less than or equal to Q3 + 1.5 * IQR.
# The lower whisker ends at the smallest data value greater than or equal to Q1 - 1.5 * IQR.
# Data points that lie beyond these calculated boundaries are statistically deemed outliers and are explicitly drawn as individual points to highlight them.

# %% [markdown]
# **Conclusion**
#
# Thus we have learned about basics of Contour plots, Histograms, Box plots.
